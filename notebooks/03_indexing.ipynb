# %%
import pandas as pd

df = pd.DataFrame({
    "나이": [25,30,28,35],
    "도시": ["서울", "부산", "서울", "대구"],
    "점수": [90, 85, 95, 70],
}, index=["철수", "영희", "민수", "지수"])

print(df)
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 영희  30  부산  85
# 민수  28  서울  95
# 지수  35  대구  70

# %%
df.loc["영희"]
# Out:
# 나이    30
# 도시    부산
# 점수    85
# Name: 영희, dtype: object

# %%
df.loc["영희", "점수"]
# Out:
# np.int64(85)

# %%
df.loc["철수": "민수"]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 영희  30  부산  85
# 민수  28  서울  95

# %%
df.loc[:, "도시"]
# Out:
# 철수    서울
# 영희    부산
# 민수    서울
# 지수    대구
# Name: 도시, dtype: str

# %%
df.loc[["철수", "지수"], ["나이", "점수"]]
# Out:
#     나이  점수
# 철수  25  90
# 지수  35  70

# %%
df.iloc[0]
# Out:
# 나이    25
# 도시    서울
# 점수    90
# Name: 철수, dtype: object

# %%
df.iloc[1, 2]
# Out:
# np.int64(85)

# %%
df.iloc[0:2]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 영희  30  부산  85

# %%
df.iloc[:, 0]
# Out:
# 철수    25
# 영희    30
# 민수    28
# 지수    35
# Name: 나이, dtype: int64

# %%
df.iloc[[0,3],[0,2]]
# Out:
#     나이  점수
# 철수  25  90
# 지수  35  70

# %%
df[df["나이"] >= 30]
# Out:
#     나이  도시  점수
# 영희  30  부산  85
# 지수  35  대구  70

# %%
df[df["도시"] == "서울"]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95

# %%
df[(df["나이"] >= 28) & (df["점수"] >= 90)]
# Out:
#     나이  도시  점수
# 민수  28  서울  95

# %%
df.loc[df["도시"] == "서울", "점수"]
# Out:
# 철수    90
# 민수    95
# Name: 점수, dtype: int64

# %%
df.loc['민수', '나이']
# Out:
# np.int64(28)

# %%
df.iloc[2, 0].item()
# Out:
# 28

# %%
df.iloc[-1, -1].item()
# Out:
# 70

# %%
df[(df['점수'] >= 90)]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95

# %%
df[(df['도시'] == '서울') & (df['점수'] >= 90)]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95

# %%
df.loc["철수":"민수"]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 영희  30  부산  85
# 민수  28  서울  95

# %%
df.iloc[0:2]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 영희  30  부산  85

# %% [markdown]
# loc은 철수와 민수 index를 포함
# iloc은 2를 포함 X

# %%
# 기존 방식
df[(df["나이"] >= 28 ) & (df["점수"] >= 90)]
# Out:
#     나이  도시  점수
# 민수  28  서울  95

# %%
# query 방식 - 같은 결과, 더 읽기 쉬움
df.query("나이 >= 28 and 점수 >= 90")
# Out:
#     나이  도시  점수
# 민수  28  서울  95

# %%
df.query("도시 == '서울'")
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95

# %%
df.query("나이 >= 28 and 점수 >= 90")
# Out:
#     나이  도시  점수
# 민수  28  서울  95

# %%
df.query("점수 > 80 or 도시 == '대구'")
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 영희  30  부산  85
# 민수  28  서울  95
# 지수  35  대구  70

# %%
기준점수 = 90

df.query("점수 >= @기준점수")
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95

# %%
df[df["도시"].isin(["서울", "대구"])]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95
# 지수  35  대구  70

# %%
df[(df["도시"] == "서울") | (df["도시"] == "대구")]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95
# 지수  35  대구  70

# %%
df[~df["도시"].isin(["서울"])]
# Out:
#     나이  도시  점수
# 영희  30  부산  85
# 지수  35  대구  70

# %%
df[df["나이"].between(28, 35)]
# Out:
#     나이  도시  점수
# 영희  30  부산  85
# 민수  28  서울  95
# 지수  35  대구  70

# %%
df[(df["나이"] >= 28) & (df["나이"] <= 35)]
# Out:
#     나이  도시  점수
# 영희  30  부산  85
# 민수  28  서울  95
# 지수  35  대구  70

# %%
# '도시'를 인덱스로 (기존 이름 인덱스는 사라짐)
df2 = df.set_index("도시")
print(df2)

df2.reset_index()
# Out:
#     나이  점수
# 도시
# 서울  25  90
# 부산  30  85
# 서울  28  95
# 대구  35  70
#    도시  나이  점수
# 0  서울  25  90
# 1  부산  30  85
# 2  서울  28  95
# 3  대구  35  70

# %%
df.query("점수 > 85")
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95

# %%
df[df['도시'].isin(['서울'])]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95

# %%
df[df['점수'].between(80, 90)]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 영희  30  부산  85

# %%
최소나이 = 30

df.query("나이 >= @최소나이")
# Out:
#     나이  도시  점수
# 영희  30  부산  85
# 지수  35  대구  70

# %%
df.set_index("도시").loc["서울"]
# Out:
#     나이  점수
# 도시
# 서울  25  90
# 서울  28  95

# %%
df.loc[["철수", "민수"]]
df[df.index.isin(["철수", "민수"])]
# Out:
#     나이  도시  점수
# 철수  25  서울  90
# 민수  28  서울  95

# %%
df.set_index("도시").index.is_unique
# Out:
# False
